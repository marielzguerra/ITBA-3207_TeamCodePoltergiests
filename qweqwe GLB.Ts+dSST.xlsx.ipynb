# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
dataset2 = pd.read_excel(r"Proposal's Data Sets\GLB.Ts+dSST.xlsx")

# %%
dataset2
# Out:
#     Land-Ocean: Global Means Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       Year        Jan        Feb        Mar        Apr
# 1                       1880      -0.17      -0.23      -0.08      -0.15
# 2                       1881      -0.18      -0.13       0.04       0.06
# 3                       1882       0.17       0.15       0.05      -0.16
# 4                       1883      -0.28      -0.36      -0.12      -0.18
# ..                       ...        ...        ...        ...        ...
# 139                     2018       0.81       0.85       0.89       0.88
# 140                     2019       0.93       0.95       1.18       1.01
# 141                     2020       1.16       1.24       1.17       1.13
# 142                     2021       0.82       0.65       0.89       0.76
# 143                     2022       0.91        0.9        ***        ***
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
type(dataset2)
# Out:
# pandas.core.frame.DataFrame
