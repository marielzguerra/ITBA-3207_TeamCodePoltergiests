# %%
import pandas as pd
dataset1=pd.read_excel(r"Proposal's Data Sets\co2-emissions-and-gdp (2).xlsx")
datasetA=pd.DataFrame(dataset1)
datasetA
# Out:
#            Entity Code  Year  Annual_CO2_emissions  \
# 0     Afghanistan  AFG  1990             2603238.0
# 1     Afghanistan  AFG  1991             2427366.0
# 2     Afghanistan  AFG  1992             1379462.0
# 3     Afghanistan  AFG  1993             1333055.0
# 4     Afghanistan  AFG  1994             1281602.0
# ...           ...  ...   ...                   ...
# 8341     Zimbabwe  ZWE  2015            12225821.0
# 8342     Zimbabwe  ZWE  2016            10737567.0
# 8343     Zimbabwe  ZWE  2017             9581633.0
# 8344     Zimbabwe  ZWE  2018            11854367.0
# 8345     Zimbabwe  ZWE  2019            10949084.0
#
#       Annual_consumption_based_CO2_emissions  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# ...

# %%
datasetA=datasetA.fillna(0)
datasetA
# Out:
#            Entity Code  Year  Annual_CO2_emissions  \
# 0     Afghanistan  AFG  1990             2603238.0
# 1     Afghanistan  AFG  1991             2427366.0
# 2     Afghanistan  AFG  1992             1379462.0
# 3     Afghanistan  AFG  1993             1333055.0
# 4     Afghanistan  AFG  1994             1281602.0
# ...           ...  ...   ...                   ...
# 8341     Zimbabwe  ZWE  2015            12225821.0
# 8342     Zimbabwe  ZWE  2016            10737567.0
# 8343     Zimbabwe  ZWE  2017             9581633.0
# 8344     Zimbabwe  ZWE  2018            11854367.0
# 8345     Zimbabwe  ZWE  2019            10949084.0
#
#       Annual_consumption_based_CO2_emissions  \
# 0                               0.000000e+00
# 1                               0.000000e+00
# 2                               0.000000e+00
# 3                               0.000000e+00
# 4                               0.000000e+00
# ...                                      ...
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(r"Proposal's Data Sets\co2-emissions-and-gdp (2).xlsx")
plt.show()

# %%
#carbon emission of each counrtry

# %%
afg = datasetA[datasetA.Entity == 'Afghanistan']
alb = datasetA[datasetA.Entity == 'Albania']
dza = datasetA[datasetA.Entity == 'Algeria']
And = datasetA[datasetA.Entity == 'Andorra']
ago = datasetA[datasetA.Entity == 'Angola']
aia = datasetA[datasetA.Entity == 'Anguilla']
ata = datasetA[datasetA.Entity == 'Antartica']
atg = datasetA[datasetA.Entity == 'Antigua and Barbuda']
arw = datasetA[datasetA.Entity == 'Arab world']
arg = datasetA[datasetA.Entity == 'Argentina']
arm = datasetA[datasetA.Entity == 'Armenia']
abw = datasetA[datasetA.Entity == 'Aruba']
aus = datasetA[datasetA.Entity == 'Australia']
aut = datasetA[datasetA.Entity == 'Austria']
aze = datasetA[datasetA.Entity == 'Azerbaijan']
bhs = datasetA[datasetA.Entity == 'Bahamas']
bhr = datasetA[datasetA.Entity == 'Bahrain']
bgd = datasetA[datasetA.Entity == 'Bangladesh']
brb = datasetA[datasetA.Entity == 'Barbados']
blr = datasetA[datasetA.Entity == 'Belarus']
bel = datasetA[datasetA.Entity == 'Belgium']
blz = datasetA[datasetA.Entity == 'Belize']
ben = datasetA[datasetA.Entity == 'Benin']
bmu = datasetA[datasetA.Entity == 'Bermuda']
btn = datasetA[datasetA.Entity == 'Bhutan']
bol = datasetA[datasetA.Entity == 'Bolivia']
bes = datasetA[datasetA.Entity == 'Bonaire Sint Eustatius and Saba']
bih = datasetA[datasetA.Entity == 'Bosnia and Herzegovina']
bwa = datasetA[datasetA.Entity == 'Bostwana']
bra = datasetA[datasetA.Entity == 'Brazil']
vgb = datasetA[datasetA.Entity == 'British Virgin Island']
brn = datasetA[datasetA.Entity == 'Brunei']
bgr = datasetA[datasetA.Entity == 'Bulgaria']
bfa = datasetA[datasetA.Entity == 'Burkina Faso']
bdi = datasetA[datasetA.Entity == 'Burundi']
khm = datasetA[datasetA.Entity == 'Cambodia']
cmr = datasetA[datasetA.Entity == 'Cameron']
can = datasetA[datasetA.Entity == 'Canada']
cpv = datasetA[datasetA.Entity == 'Cape Verde']
css = datasetA[datasetA.Entity == 'Caribbean Small States']
cym = datasetA[datasetA.Entity == 'Cayman Islands']
caf = datasetA[datasetA.Entity == 'Central African Republic']
ceb = datasetA[datasetA.Entity == 'Central Europe and Baltics']
tcd = datasetA[datasetA.Entity == 'Chad']
chl = datasetA[datasetA.Entity == 'Chile']
chn = datasetA[datasetA.Entity == 'China']
col = datasetA[datasetA.Entity == 'Colombia']
com = datasetA[datasetA.Entity == 'Comoros']
cog = datasetA[datasetA.Entity == 'Congo']
cok = datasetA[datasetA.Entity == 'Cook Islands']
cri = datasetA[datasetA.Entity == 'Costa Rica']
hrv = datasetA[datasetA.Entity == 'Croatia']
cub = datasetA[datasetA.Entity == 'Cuba']
cuw = datasetA[datasetA.Entity == 'Curacao']
cyp = datasetA[datasetA.Entity == 'Cyprus']
cze = datasetA[datasetA.Entity == 'Czechia']
cod = datasetA[datasetA.Entity == 'Democratic Republic of Congo']
dnk = datasetA[datasetA.Entity == 'Denmark']
dji = datasetA[datasetA.Entity == 'Djibouti']
dma = datasetA[datasetA.Entity == 'Dominica']
dom = datasetA[datasetA.Entity == 'Dominican Republic']
ecu = datasetA[datasetA.Entity == 'Ecuador']
egy = datasetA[datasetA.Entity == 'Egypt']
slv = datasetA[datasetA.Entity == 'El Salvador']
gnq = datasetA[datasetA.Entity == 'Equatorial Guinea']
eri = datasetA[datasetA.Entity == 'Eritrea']
est = datasetA[datasetA.Entity == 'Estonia']
swz = datasetA[datasetA.Entity == 'Eswatini']
eth = datasetA[datasetA.Entity == 'Ethiopia']
fro = datasetA[datasetA.Entity == 'Faeroe Islands']
fji = datasetA[datasetA.Entity == 'Fiji']
fin = datasetA[datasetA.Entity == 'Finland']
fra = datasetA[datasetA.Entity == 'France']
guf = datasetA[datasetA.Entity == 'French Guiana']
pyf = datasetA[datasetA.Entity == 'French Polynesia']
gab = datasetA[datasetA.Entity == 'Gabon']
gmb = datasetA[datasetA.Entity == 'Gambia']
geo = datasetA[datasetA.Entity == 'Georgia']
deu = datasetA[datasetA.Entity == 'Germany']
gha = datasetA[datasetA.Entity == 'Ghana']
grc = datasetA[datasetA.Entity == 'Greece']
grl = datasetA[datasetA.Entity == 'Greenland']
grd = datasetA[datasetA.Entity == 'Grenada']
glp = datasetA[datasetA.Entity == 'Guadeloupe']
gtm = datasetA[datasetA.Entity == 'Guatemala']
gin = datasetA[datasetA.Entity == 'Guinea']
gnb = datasetA[datasetA.Entity == 'Guinea-Bissau']
guy = datasetA[datasetA.Entity == 'Guyana']
hti = datasetA[datasetA.Entity == 'Haiti']
hnd = datasetA[datasetA.Entity == 'Honduras']
hkg = datasetA[datasetA.Entity == 'Hong Kong']
hun = datasetA[datasetA.Entity == 'Hungary']
isl = datasetA[datasetA.Entity == 'Iceland']
ind = datasetA[datasetA.Entity == 'India']
idn = datasetA[datasetA.Entity == 'Indonesia']
irn = datasetA[datasetA.Entity == 'Iran']
irq = datasetA[datasetA.Entity == 'Iraq']
irl = datasetA[datasetA.Entity == 'Ireland']
isr = datasetA[datasetA.Entity == 'Israel']
ita = datasetA[datasetA.Entity == 'Italy']
jam = datasetA[datasetA.Entity == 'Jamaica']
jpn = datasetA[datasetA.Entity == 'Japan']
jor = datasetA[datasetA.Entity == 'Jordan']
kaz = datasetA[datasetA.Entity == 'Kazakhstan']
ken = datasetA[datasetA.Entity == 'Kenya']
kir = datasetA[datasetA.Entity == 'Kiribati']
owid_kos = datasetA[datasetA.Entity == 'Kosovo']
kwt = datasetA[datasetA.Entity == 'Kuwait']
kgz = datasetA[datasetA.Entity == 'Kyrgyzstan']
lao = datasetA[datasetA.Entity == 'Laos']
lva = datasetA[datasetA.Entity == 'Latvia']
lbn = datasetA[datasetA.Entity == 'Lebanon']
lso = datasetA[datasetA.Entity == 'Lesotho']
lbr = datasetA[datasetA.Entity == 'Liberia']
lby = datasetA[datasetA.Entity == 'Libya']
lie = datasetA[datasetA.Entity == 'Liechtenstein']
ltu = datasetA[datasetA.Entity == 'Lithuania']
lux = datasetA[datasetA.Entity == 'Luxemburg']
mac = datasetA[datasetA.Entity == 'Macao']
mdg = datasetA[datasetA.Entity == 'Madagascar']
mwi = datasetA[datasetA.Entity == 'Malawi']
mys = datasetA[datasetA.Entity == 'Malaysia']
mdv = datasetA[datasetA.Entity == 'Maldives']
mli = datasetA[datasetA.Entity == 'Mali']
mlt = datasetA[datasetA.Entity == 'Malta']
mhl = datasetA[datasetA.Entity == 'Marshall Islands']
mtq = datasetA[datasetA.Entity == 'Martinique']
mrt = datasetA[datasetA.Entity == 'Mauritania']
mus =datasetA[datasetA.Entity == 'Mauritius']
myt = datasetA[datasetA.Entity == 'Mayotte']
mex = datasetA[datasetA.Entity == 'Mexico']
fsm = datasetA[datasetA.Entity == 'Micronesia(country)']
mda = datasetA[datasetA.Entity == 'Maldova']
mng = datasetA[datasetA.Entity == 'Mongolia']
mne = datasetA[datasetA.Entity == 'Montenegro']
msr = datasetA[datasetA.Entity == 'Montserrat']
mar = datasetA[datasetA.Entity == 'Morocco']
moz = datasetA[datasetA.Entity == 'Mozambique']
mmr = datasetA[datasetA.Entity == 'Myanmar']
nam = datasetA[datasetA.Entity == 'Nambia']
nru = datasetA[datasetA.Entity == 'Nauru']
npl = datasetA[datasetA.Entity == 'Nepal']
nld = datasetA[datasetA.Entity == 'Netherlands']
ncl = datasetA[datasetA.Entity == 'New Caledonia']
nzl = datasetA[datasetA.Entity == 'New Zealand']
nic = datasetA[datasetA.Entity == 'Nicaragua']
new = datasetA[datasetA.Entity == 'Niger']
nga = datasetA[datasetA.Entity == 'Nigeria']
niu = datasetA[datasetA.Entity == 'Niue']
prk = datasetA[datasetA.Entity == 'North Korea']
mkd = datasetA[datasetA.Entity == 'Norway']
omn = datasetA[datasetA.Entity == 'Oman']
pak = datasetA[datasetA.Entity == 'Pakistan']
plw = datasetA[datasetA.Entity == 'Palau']
pse = datasetA[datasetA.Entity == 'Palestine']
pan = datasetA[datasetA.Entity == 'Panama']
png = datasetA[datasetA.Entity == 'Papua New Guinea']
pry = datasetA[datasetA.Entity == 'Paraguay']
per = datasetA[datasetA.Entity == 'Peru']
phl = datasetA[datasetA.Entity == 'Philippines']
pol = datasetA[datasetA.Entity == 'Poland']
prt = datasetA[datasetA.Entity == 'Portugal']
pri = datasetA[datasetA.Entity == 'Puerto Rico']
qat =datasetA[datasetA.Entity == 'Qatar']
reu = datasetA[datasetA.Entity == 'Reunion']
rou = datasetA[datasetA.Entity == 'Romania']
rus = datasetA[datasetA.Entity == 'Russia']
rwa = datasetA[datasetA.Entity == 'Rwanda']
shn = datasetA[datasetA.Entity == 'Saint Helena']
kna = datasetA[datasetA.Entity == 'Saint Kits and Newis']
lca = datasetA[datasetA.Entity == 'Saint Lucia']
spm = datasetA[datasetA.Entity == 'Saint Peirre Miquelon']
vct = datasetA[datasetA.Entity == 'Saint Vincent and the Grenadines']
wsm = datasetA[datasetA.Entity == 'Samoa']
smr = datasetA[datasetA.Entity == 'San Marino']
stp = datasetA[datasetA.Entity == 'Sao Tome and Principe']
sau = datasetA[datasetA.Entity == 'Saudi Arabia']
sen = datasetA[datasetA.Entity == 'Senegal']
srb = datasetA[datasetA.Entity == 'Serbia']
syc = datasetA[datasetA.Entity == 'Seychelles']
sle = datasetA[datasetA.Entity == 'Sierra Leone']
sgp = datasetA[datasetA.Entity == 'Singapore']
sxm = datasetA[datasetA.Entity == 'Sint Maarten(Dutch part)']
svk = datasetA[datasetA.Entity == 'Slovakia']
svn = datasetA[datasetA.Entity == 'Slovenia']
slb = datasetA[datasetA.Entity == 'Solomon Islands']
som = datasetA[datasetA.Entity == 'Somalia']
zaf = datasetA[datasetA.Entity == 'South Africa']
kor = datasetA[datasetA.Entity == 'South Korea']
ssd = datasetA[datasetA.Entity == 'South Sudan']
esp = datasetA[datasetA.Entity == 'Spain']
lka = datasetA[datasetA.Entity == 'Sri Lanka']
sdn = datasetA[datasetA.Entity == 'Sudan']
sur = datasetA[datasetA.Entity == 'Suriname']
swe = datasetA[datasetA.Entity == 'Sweden']
che = datasetA[datasetA.Entity == 'Switzerland']
syr = datasetA[datasetA.Entity == 'Syria']
twn = datasetA[datasetA.Entity == 'Taiwan']
tjk = datasetA[datasetA.Entity == 'Tajikistan']
tza = datasetA[datasetA.Entity == 'Tanzania']
tha = datasetA[datasetA.Entity == 'Thailand']
tls = datasetA[datasetA.Entity == 'Timor']
tgo = datasetA[datasetA.Entity == 'Togo']
ton = datasetA[datasetA.Entity == 'Tonga']
tto = datasetA[datasetA.Entity == 'Trinidad and Tobago']
tun = datasetA[datasetA.Entity == 'Tunisia']
tur = datasetA[datasetA.Entity == 'Turkey']
tkm = datasetA[datasetA.Entity == 'Turkmenistan']
tca = datasetA[datasetA.Entity == 'Turks and Caicos Islands']
tuv = datasetA[datasetA.Entity == 'Tuvalu']
uga = datasetA[datasetA.Entity == 'Uganda']
ukr = datasetA[datasetA.Entity == 'Ukraine']
are = datasetA[datasetA.Entity == 'United Arab Emirates']
gbr = datasetA[datasetA.Entity == 'United Kingdom']
usa = datasetA[datasetA.Entity == 'United States']
ury = datasetA[datasetA.Entity == 'Uruguay']
uzb = datasetA[datasetA.Entity == 'Uzbekistan']
vut = datasetA[datasetA.Entity == 'Vanuatu']
ven = datasetA[datasetA.Entity == 'Venezuela']
vnm = datasetA[datasetA.Entity == 'Vietnam']
wlf = datasetA[datasetA.Entity == 'Wallis and Futuna']
yem = datasetA[datasetA.Entity == 'Yemen']
zmb = datasetA[datasetA.Entity == 'Zambia']
zwe = datasetA[datasetA.Entity == 'Zimbabwe']

# %%
fig1 = plt.figure()
fig1.set_size_inches(20, 15)
plt.plot(afg.Year, afg.Annual_CO2_emissions / 10**6, color = '#CD5C5C')
plt.plot(alb.Year, alb.Annual_CO2_emissions / 10**6, color = '#FF0000')
plt.plot(dza.Year, dza.Annual_CO2_emissions / 10**6)
plt.plot(And.Year, And.Annual_CO2_emissions / 10**6)
plt.plot(ago.Year, ago.Annual_CO2_emissions / 10**6)
plt.plot(aia.Year, aia.Annual_CO2_emissions / 10**6)
plt.plot(ata.Year, ata.Annual_CO2_emissions / 10**6)
plt.plot(atg.Year, atg.Annual_CO2_emissions / 10**6)
plt.plot(arw.Year, arw.Annual_CO2_emissions / 10**6)
plt.plot(arg.Year, arg.Annual_CO2_emissions / 10**6)
plt.plot(arm.Year, arm.Annual_CO2_emissions / 10**6)
plt.plot(abw.Year, abw.Annual_CO2_emissions / 10**6)
plt.plot(aus.Year, aus.Annual_CO2_emissions / 10**6)
plt.plot(aut.Year, aut.Annual_CO2_emissions / 10**6)
plt.plot(aze.Year, aze.Annual_CO2_emissions / 10**6)
plt.plot(bhs.Year, bhs.Annual_CO2_emissions / 10**6)
plt.plot(bhr.Year, bhr.Annual_CO2_emissions / 10**6)
plt.plot(bgd.Year, bgd.Annual_CO2_emissions / 10**6)
plt.plot(brb.Year, brb.Annual_CO2_emissions / 10**6)
plt.plot(blr.Year, blr.Annual_CO2_emissions / 10**6)
plt.plot(bel.Year, bel.Annual_CO2_emissions / 10**6)
plt.plot(blz.Year, blz.Annual_CO2_emissions / 10**6)
plt.plot(ben.Year, ben.Annual_CO2_emissions / 10**6)
plt.plot(bmu.Year, bmu.Annual_CO2_emissions / 10**6)
plt.plot(btn.Year, btn.Annual_CO2_emissions / 10**6)
plt.plot(bol.Year, bol.Annual_CO2_emissions / 10**6)
plt.plot(bes.Year, bes.Annual_CO2_emissions / 10**6)
plt.plot(bih.Year, bih.Annual_CO2_emissions / 10**6)
plt.plot(bwa.Year, bwa.Annual_CO2_emissions / 10**6)
plt.plot(bra.Year, bra.Annual_CO2_emissions / 10**6)
plt.plot(vgb.Year, vgb.Annual_CO2_emissions / 10**6)
plt.plot(brn.Year, brn.Annual_CO2_emissions / 10**6)
plt.plot(bgr.Year, bgr.Annual_CO2_emissions / 10**6)
plt.plot(bfa.Year, bfa.Annual_CO2_emissions / 10**6)
plt.plot(bdi.Year, bdi.Annual_CO2_emissions / 10**6)
plt.plot(khm.Year, khm.Annual_CO2_emissions / 10**6)
plt.plot(cmr.Year, cmr.Annual_CO2_emissions / 10**6)
plt.plot(can.Year, can.Annual_CO2_emissions / 10**6)
plt.plot(cpv.Year, cpv.Annual_CO2_emissions / 10**6)
plt.plot(css.Year, css.Annual_CO2_emissions / 10**6)
plt.plot(cym.Year, cym.Annual_CO2_emissions / 10**6)
plt.plot(caf.Year, caf.Annual_CO2_emissions / 10**6)
plt.plot(ceb.Year, ceb.Annual_CO2_emissions / 10**6)
plt.plot(tcd.Year, tcd.Annual_CO2_emissions / 10**6)
plt.plot(chl.Year, chl.Annual_CO2_emissions / 10**6)
plt.plot(chn.Year, chn.Annual_CO2_emissions / 10**6)
plt.plot(col.Year, col.Annual_CO2_emissions / 10**6)
plt.plot(com.Year, com.Annual_CO2_emissions / 10**6)
plt.plot(cog.Year, cog.Annual_CO2_emissions / 10**6)
plt.plot(cok.Year, cok.Annual_CO2_emissions / 10**6)
plt.plot(cri.Year, cri.Annual_CO2_emissions / 10**6)
plt.plot(hrv.Year, hrv.Annual_CO2_emissions / 10**6)
plt.plot(cub.Year, cub.Annual_CO2_emissions / 10**6)
plt.plot(cuw.Year, cuw.Annual_CO2_emissions / 10**6)
plt.plot(cyp.Year, cyp.Annual_CO2_emissions / 10**6)
plt.plot(cze.Year, cze.Annual_CO2_emissions / 10**6)
plt.plot(cod.Year, cod.Annual_CO2_emissions / 10**6)
plt.plot(dnk.Year, dnk.Annual_CO2_emissions / 10**6)
plt.plot(dji.Year, dji.Annual_CO2_emissions / 10**6)
plt.plot(dma.Year, dma.Annual_CO2_emissions / 10**6)
plt.plot(dom.Year, dom.Annual_CO2_emissions / 10**6)
plt.plot(ecu.Year, ecu.Annual_CO2_emissions / 10**6)
plt.plot(egy.Year, egy.Annual_CO2_emissions / 10**6)
plt.plot(slv.Year, slv.Annual_CO2_emissions / 10**6)
plt.plot(gnq.Year, gnq.Annual_CO2_emissions / 10**6)
plt.plot(eri.Year, eri.Annual_CO2_emissions / 10**6)
plt.plot(est.Year, est.Annual_CO2_emissions / 10**6)
plt.plot(swz.Year, swz.Annual_CO2_emissions / 10**6)
plt.plot(eth.Year, eth.Annual_CO2_emissions / 10**6)
plt.plot(fro.Year, fro.Annual_CO2_emissions / 10**6)
plt.plot(fji.Year, fji.Annual_CO2_emissions / 10**6)
plt.plot(fin.Year, fin.Annual_CO2_emissions / 10**6)
plt.plot(fra.Year, fra.Annual_CO2_emissions / 10**6)
plt.plot(guf.Year, guf.Annual_CO2_emissions / 10**6)
plt.plot(pyf.Year, pyf.Annual_CO2_emissions / 10**6)
plt.plot(gab.Year, gab.Annual_CO2_emissions / 10**6)
plt.plot(gmb.Year, gmb.Annual_CO2_emissions / 10**6)
plt.plot(geo.Year, geo.Annual_CO2_emissions / 10**6)
plt.plot(deu.Year, deu.Annual_CO2_emissions / 10**6)
plt.plot(gha.Year, gha.Annual_CO2_emissions / 10**6)
plt.plot(grc.Year, grc.Annual_CO2_emissions / 10**6)
plt.plot(grl.Year, grl.Annual_CO2_emissions / 10**6)
plt.plot(grd.Year, grd.Annual_CO2_emissions / 10**6)
plt.plot(glp.Year, glp.Annual_CO2_emissions / 10**6)
plt.plot(gtm.Year, gtm.Annual_CO2_emissions / 10**6)
plt.plot(gin.Year, gin.Annual_CO2_emissions / 10**6)
plt.plot(gnb.Year, gnb.Annual_CO2_emissions / 10**6)
plt.plot(guy.Year, guy.Annual_CO2_emissions / 10**6)
plt.plot(hti.Year, hti.Annual_CO2_emissions / 10**6)
plt.plot(hnd.Year, hnd.Annual_CO2_emissions / 10**6)
plt.plot(hkg.Year, hkg.Annual_CO2_emissions / 10**6)
plt.plot(hun.Year, hun.Annual_CO2_emissions / 10**6)
plt.plot(isl.Year, isl.Annual_CO2_emissions / 10**6)
plt.plot(ind.Year, ind.Annual_CO2_emissions / 10**6)
plt.plot(idn.Year, idn.Annual_CO2_emissions / 10**6)
plt.plot(irn.Year, irn.Annual_CO2_emissions / 10**6)
plt.plot(irq.Year, irq.Annual_CO2_emissions / 10**6)
plt.plot(irl.Year, irl.Annual_CO2_emissions / 10**6)
plt.plot(isr.Year, isr.Annual_CO2_emissions / 10**6)
plt.plot(ita.Year, ita.Annual_CO2_emissions / 10**6)
plt.plot(jam.Year, jam.Annual_CO2_emissions / 10**6)
plt.plot(jpn.Year, jpn.Annual_CO2_emissions / 10**6)
plt.plot(jor.Year, jor.Annual_CO2_emissions / 10**6)
plt.plot(kaz.Year, kaz.Annual_CO2_emissions / 10**6)
plt.plot(ken.Year, ken.Annual_CO2_emissions / 10**6)
plt.plot(kir.Year, kir.Annual_CO2_emissions / 10**6)
plt.plot(owid_kos.Year, owid_kos.Annual_CO2_emissions / 10**6)
plt.plot(kwt.Year, kwt.Annual_CO2_emissions / 10**6)
plt.plot(kgz.Year, kgz.Annual_CO2_emissions / 10**6)
plt.plot(lao.Year, lao.Annual_CO2_emissions / 10**6)
plt.plot(lva.Year, lva.Annual_CO2_emissions / 10**6)
plt.plot(lbn.Year, lbn.Annual_CO2_emissions / 10**6)
plt.plot(lso.Year, lso.Annual_CO2_emissions / 10**6)
plt.plot(lbr.Year, lbr.Annual_CO2_emissions / 10**6)
plt.plot(lby.Year, lby.Annual_CO2_emissions / 10**6)
plt.plot(lie.Year, lie.Annual_CO2_emissions / 10**6)
plt.plot(ltu.Year, ltu.Annual_CO2_emissions / 10**6)
plt.plot(lux.Year, lux.Annual_CO2_emissions / 10**6)
plt.plot(mac.Year, mac.Annual_CO2_emissions / 10**6)
plt.plot(mdg.Year, mdg.Annual_CO2_emissions / 10**6)
plt.plot(mwi.Year, mwi.Annual_CO2_emissions / 10**6)
plt.plot(mys.Year, mys.Annual_CO2_emissions / 10**6)
plt.plot(mdv.Year, mdv.Annual_CO2_emissions / 10**6)
plt.plot(mli.Year, mli.Annual_CO2_emissions / 10**6)
plt.plot(mlt.Year, mlt.Annual_CO2_emissions / 10**6)
plt.plot(mhl.Year, mhl.Annual_CO2_emissions / 10**6)
plt.plot(mtq.Year, mtq.Annual_CO2_emissions / 10**6)
plt.plot(mrt.Year, mrt.Annual_CO2_emissions / 10**6)
plt.plot(mus.Year, mus.Annual_CO2_emissions / 10**6)
plt.plot(myt.Year, myt.Annual_CO2_emissions / 10**6)
plt.plot(mex.Year, mex.Annual_CO2_emissions / 10**6)
plt.plot(fsm.Year, fsm.Annual_CO2_emissions / 10**6)
plt.plot(mda.Year, mda.Annual_CO2_emissions / 10**6)
plt.plot(mng.Year, mng.Annual_CO2_emissions / 10**6)
plt.plot(mne.Year, mne.Annual_CO2_emissions / 10**6)
plt.plot(msr.Year, msr.Annual_CO2_emissions / 10**6)
plt.plot(mar.Year, mar.Annual_CO2_emissions / 10**6)
plt.plot(moz.Year, moz.Annual_CO2_emissions / 10**6)
plt.plot(mmr.Year, mmr.Annual_CO2_emissions / 10**6)
plt.plot(nam.Year, nam.Annual_CO2_emissions / 10**6)
plt.plot(nru.Year, nru.Annual_CO2_emissions / 10**6)
plt.plot(npl.Year, npl.Annual_CO2_emissions / 10**6)
plt.plot(nld.Year, nld.Annual_CO2_emissions / 10**6)
plt.plot(ncl.Year, ncl.Annual_CO2_emissions / 10**6)
plt.plot(nzl.Year, nzl.Annual_CO2_emissions / 10**6)
plt.plot(nic.Year, nic.Annual_CO2_emissions / 10**6)
plt.plot(new.Year, new.Annual_CO2_emissions / 10**6)
plt.plot(nga.Year, nga.Annual_CO2_emissions / 10**6)
plt.plot(niu.Year, niu.Annual_CO2_emissions / 10**6)
plt.plot(prk.Year, prk.Annual_CO2_emissions / 10**6)
plt.plot(mkd.Year, mkd.Annual_CO2_emissions / 10**6)
plt.plot(omn.Year, omn.Annual_CO2_emissions / 10**6)
plt.plot(pak.Year, pak.Annual_CO2_emissions / 10**6)
plt.plot(plw.Year, plw.Annual_CO2_emissions / 10**6)
plt.plot(pse.Year, pse.Annual_CO2_emissions / 10**6)
plt.plot(pan.Year, pan.Annual_CO2_emissions / 10**6)
plt.plot(png.Year, png.Annual_CO2_emissions / 10**6)
plt.plot(pry.Year, pry.Annual_CO2_emissions / 10**6)
plt.plot(per.Year, per.Annual_CO2_emissions / 10**6)
plt.plot(phl.Year, phl.Annual_CO2_emissions / 10**6)
plt.plot(pol.Year, pol.Annual_CO2_emissions / 10**6)
plt.plot(prt.Year, prt.Annual_CO2_emissions / 10**6)
plt.plot(pri.Year, pri.Annual_CO2_emissions / 10**6)
plt.plot(qat.Year, qat.Annual_CO2_emissions / 10**6)
plt.plot(reu.Year, reu.Annual_CO2_emissions / 10**6)
plt.plot(rou.Year, rou.Annual_CO2_emissions / 10**6)
plt.plot(rus.Year, rus.Annual_CO2_emissions / 10**6)
plt.plot(rwa.Year, rwa.Annual_CO2_emissions / 10**6)
plt.plot(shn.Year, shn.Annual_CO2_emissions / 10**6)
plt.plot(kna.Year, kna.Annual_CO2_emissions / 10**6)
plt.plot(lca.Year, lca.Annual_CO2_emissions / 10**6)
plt.plot(spm.Year, spm.Annual_CO2_emissions / 10**6)
plt.plot(vct.Year, vct.Annual_CO2_emissions / 10**6)
plt.plot(wsm.Year, wsm.Annual_CO2_emissions / 10**6)
plt.plot(smr.Year, smr.Annual_CO2_emissions / 10**6)
plt.plot(stp.Year, stp.Annual_CO2_emissions / 10**6)
plt.plot(sau.Year, sau.Annual_CO2_emissions / 10**6)
plt.plot(sen.Year, sen.Annual_CO2_emissions / 10**6)
plt.plot(srb.Year, srb.Annual_CO2_emissions / 10**6)
plt.plot(syc.Year, syc.Annual_CO2_emissions / 10**6)
plt.plot(sle.Year, sle.Annual_CO2_emissions / 10**6)
plt.plot(sgp.Year, sgp.Annual_CO2_emissions / 10**6)
plt.plot(sxm.Year, sxm.Annual_CO2_emissions / 10**6)
plt.plot(svk.Year, svk.Annual_CO2_emissions / 10**6)
plt.plot(svn.Year, svn.Annual_CO2_emissions / 10**6)
plt.plot(slb.Year, slb.Annual_CO2_emissions / 10**6)
plt.plot(som.Year, som.Annual_CO2_emissions / 10**6)
plt.plot(zaf.Year, zaf.Annual_CO2_emissions / 10**6)
plt.plot(kor.Year, kor.Annual_CO2_emissions / 10**6)
plt.plot(ssd.Year, ssd.Annual_CO2_emissions / 10**6)
plt.plot(esp.Year, esp.Annual_CO2_emissions / 10**6)
plt.plot(lka.Year, lka.Annual_CO2_emissions / 10**6)
plt.plot(sdn.Year, sdn.Annual_CO2_emissions / 10**6)
plt.plot(sur.Year, sur.Annual_CO2_emissions / 10**6)
plt.plot(swe.Year, swe.Annual_CO2_emissions / 10**6)
plt.plot(che.Year, che.Annual_CO2_emissions / 10**6)
plt.plot(syr.Year, syr.Annual_CO2_emissions / 10**6)
plt.plot(twn.Year, twn.Annual_CO2_emissions / 10**6)
plt.plot(tjk.Year, tjk.Annual_CO2_emissions / 10**6)
plt.plot(tza.Year, tza.Annual_CO2_emissions / 10**6)
plt.plot(tha.Year, tha.Annual_CO2_emissions / 10**6)
plt.plot(tls.Year, tls.Annual_CO2_emissions / 10**6)
plt.plot(tgo.Year, tgo.Annual_CO2_emissions / 10**6)
plt.plot(ton.Year, ton.Annual_CO2_emissions / 10**6)
plt.plot(tto.Year, tto.Annual_CO2_emissions / 10**6)
plt.plot(tun.Year, tun.Annual_CO2_emissions / 10**6)
plt.plot(tur.Year, tur.Annual_CO2_emissions / 10**6)
plt.plot(tkm.Year, tkm.Annual_CO2_emissions / 10**6)
plt.plot(tca.Year, tca.Annual_CO2_emissions / 10**6)
plt.plot(tuv.Year, tuv.Annual_CO2_emissions / 10**6)
plt.plot(uga.Year, uga.Annual_CO2_emissions / 10**6)
plt.plot(ukr.Year, ukr.Annual_CO2_emissions / 10**6)
plt.plot(are.Year, are.Annual_CO2_emissions / 10**6)
plt.plot(gbr.Year, gbr.Annual_CO2_emissions / 10**6)
plt.plot(usa.Year, usa.Annual_CO2_emissions / 10**6)
plt.plot(ury.Year, ury.Annual_CO2_emissions / 10**6)
plt.plot(uzb.Year, uzb.Annual_CO2_emissions / 10**6)
plt.plot(vut.Year, vut.Annual_CO2_emissions / 10**6)
plt.plot(ven.Year, ven.Annual_CO2_emissions / 10**6)
plt.plot(vnm.Year, vnm.Annual_CO2_emissions / 10**6)
plt.plot(wlf.Year, wlf.Annual_CO2_emissions / 10**6)
plt.plot(yem.Year, yem.Annual_CO2_emissions / 10**6)
plt.plot(zmb.Year, zmb.Annual_CO2_emissions / 10**6)
plt.plot(zwe.Year, zwe.Annual_CO2_emissions / 10**6)


plt.xlabel('Year')
plt.ylabel('Annual CO2 Emissions')

#legend
plt.legend(['Afghanistan', 
            'Albania', 
            'Algeria', 
            'Andorra', 
            'Angola', 
            'Anguilla',
            'Antartica', 
            'Antigua and Barbuda', 
            'Arab world', 
            'Argentina', 
            'Armenia', 
            'Aruba', 
            'Australia', 
            'Austria', 
            'Azerbaijan','Bahamas',
'Bahrain',
'Bangladesh',
'Barbados',
'Belarus',
'Belgium',
'Belize',
'Benin',
'Bermuda',
'Bhutan',
'Bolivia',
'Bonaire Sint Eustatius and Saba',
'Bosnia and Herzegovina',
'Bostwana',
'Brazil',
'British Virgin Island',
'Brunei',
'Bulgaria',
'Burkina Faso',
'Burundi',
'Cambodia',
'Cameron',
'Canada',
'Cape Verde',
'Caribbean Small States',
 'Cayman Islands',
'Central African Republic',
'Central Europe and Baltics',
'Chad',
'Chile',
'China',
'Colombia',
'Comoros',
'Congo',
'Cook Islands',
'Costa Rica',
'Croatia',
'Cuba',
'Curacao',
'Cyprus',
'Czechia',
'Democratic Republic of Congo',
 'Denmark',
'Djibouti',
'Dominica',
'Dominican Republic',
'Ecuador',
'Egypt',
'El Salvador',
'Equatorial Guinea',
 'Eritrea',
'Estonia',
'Eswatini',
'Ethiopia',
'Faeroe Islands',
'Fiji',
'Finland',
'France',
'French Guiana',
'French Polynesia',
'Gabon',
'Gambia',
'Georgia',
'Germany',
'Ghana',
'Greece',
'Greenland',
'Grenada',
'Guadeloupe',
'Guatemala',
'Guinea',
'Guinea-Bissau',
'Guyana',
'Haiti',
'Honduras',
'Hong Kong',
'Hungary',
'Iceland',
'India',
'Indonesia',
'Iran',
'Iraq',
'Ireland',
'Israel',
'Italy',
'Jamaica',
 'Japan',
'Jordan',
'Kazakhstan',
'Kenya',
'Kiribati',
'Kosovo',
'Kuwait',
'Kyrgyzstan',
 'Laos',
'Latvia',
'Lebanon',
 'Lesotho',
'Liberia',
'Libya',
'Liechtenstein',
'Lithuania',
'Luxemburg',
'Macao',
'Madagascar',
'Malawi',
'Malaysia',
'Maldives',
'Mali',
'Malta',
'Marshall Islands',
'Martinique',
'Mauritania',
'Mauritius',
'Mayotte',
'Mexico',
'Micronesia(country)',
'Maldova',
'Mongolia',
'Montenegro',
'Montserrat',
'Morocco',
'Mozambique',
'Myanmar',
'Nambia',
'Nauru',
'Nepal',
'Netherlands',
'New Caledonia',
'New Zealand',
'Nicaragua',
'Niger',
'Nigeria',
'Niue',
'North Korea',
'Norway',
'Oman',
'Pakistan',
'Palau',
'Palestine',
'Panama',
'Papua New Guinea',
'Paraguay',
'Peru',
 'Philippines',
'Poland',
'Portugal',
'Puerto Rico',
'Qatar',
'Reunion',
'Romania',
'Russia',
'Rwanda',
'Saint Helena',
'Saint Kits and Newis',
'Saint Lucia',
'Saint Peirre Miquelon',
'Saint Vincent and the Grenadines',
'Samoa',
'San Marino',
'Sao Tome and Principe',
'Saudi Arabia',
'Senegal',
'Serbia',
'Seychelles',
'Sierra Leone',
'Singapore',
'Sint Maarten(Dutch part)',
 'Slovakia',
'Slovenia',
'Solomon Islands',
'Somalia',
'South Africa',
'South Korea',
'South Sudan',
 'Spain',
'Sri Lanka',
'Sudan',
'Suriname',
'Sweden',
'Switzerland',
 'Syria',
'Taiwan',
'Tajikistan',
'Tanzania',
'Thailand',
'Timor',
'Togo',
'Tonga',
'Trinidad and Tobago',
'Tunisia',
'Turkey',
'Turkmenistan',
'Turks and Caicos Islands',
'Tuvalu',     
'Uganda',
'Ukraine'
'United Arab Emirates',
'United Kingdom',
'United States',
'Uruguay',
 'Uzbekistan',
'Vanuatu',
'Venezuela',
 'Vietnam',
'Wallis and Futuna',
'Yemen',
 'Zambia',
'Zimbabwe'],loc='center left',bbox_to_anchor=(1.0,0.5))
plt.title('Carbon Emission of Different Countries Every Year(1995-2020)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 fig1 = plt.figure()
#       2 fig1.set_size_inches(20, 15)
#       3 plt.plot(afg.Year, afg.Annual_CO2_emissions / 10**6, color = '#CD5C5C')
#
# NameError: name 'plt' is not defined
